# %%
#1
class BankAccount:

    # Constructor
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print("Deposit successful")
        else:
            print("Deposit amount must be greater than zero")

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.__balance:
                self.__balance -= amount
                print("Withdraw successful")
            else:
                print("Insufficient balance")
        else:
            print("Invalid amount")

    def get_balance(self):
        return self.__balance


# Create object
account = BankAccount()

# Deposit money
account.deposit(1000)

# Withdraw money
account.withdraw(5000)

# Display balance
print("Current Balance:", account.get_balance())
# Out:
# Deposit successful
# Insufficient balance
# Current Balance: 1000

# %%
#2

class Student:
    #constructor
      def __init__(self,marks):
          self.__marks = 0
      def set_marks(self,marks):
          self.__marks = marks
      def get_marks(self):
          return self.__marks
student1 = Student()
student.set_marks(89)
print("marks:",student.get_marks())
student1.set_marks(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 11
#       9       def get_marks(self):
#      10           return self.__marks
# ---> 11 student1 = Student()
#      12 student.set_marks(89)
#      13 print("marks:",student.get_marks())
#
# TypeError: Student.__init__() missing 1 required positional argument: 'marks'
