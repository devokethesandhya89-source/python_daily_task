# %%
#1 Write a lambda function to return the square of a number.

squared = lambda x:x*x
squared(5)
# Out:
# 25

# %%
#2 Write a lambda function to return the cube of a number.

cube = lambda x: x*x*x
cube(4)
# Out:
# 64

# %%
#3 Write a lambda function to add two numbers.

addition = lambda x,y: x+y
addition(10,20)
# Out:
# 30

# %%
#4 Write a lambda function to find the maximum of two numbers.

max_value = lambda x,y : x if x > y  else y
max(15,8)
# Out:
# 15

# %%
#5 Write a lambda function that returns "Even" if a number is even; otherwise "Odd".

number = lambda x : "even" if x % 2 == 0 else "odd"
number(9)
# Out:
# 'odd'

# %%
#6 Use map() with lambda to square every element of a list.

numbers =[1,2,3,4]
square = list(map(lambda x : x**2,lists))
print(square)
# Out:
# [1, 4, 9, 16]

# %%
#7 Use filter() with lambda to keep only even numbers.

lists =[1,2,3,4,5,6]
result = list(filter(lambda x : x % 2 == 0 ,lists ))
print(result)
# Out:
# [2, 4, 6]

# %%
#8 Use filter() with lambda to keep numbers greater than 50.

lists =[20,45,55,70]
garter = filter(lambda x : x > 50 ,lists)
print(list(garter))
# Out:
# [55, 70]

# %%
#9.Sort a list of numbers in ascending order using lambda.
[9,5,1,8,2]

lists =[9,5,1,8,2]
lists.sort( key = lambda x:x)
print(lists)
# Out:
# [1, 2, 5, 8, 9]

# %%
#Sort a list of numbers in descending order using lambda.
[9,5,1,8,2]

lists =[9,5,1,8,2]
lists.sort( reverse = lambda x:x)
print(lists)
# Out:
# [9, 8, 5, 2, 1]

# %%
#Use reduce() with lambda to find the sum of all numbers.
[10,20,30,40]

lists =[10,20,30,40]
result = reduce(lambda x, y :x + y,lists)

print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 5
#       2 [10,20,30,40]
#       4 lists =[10,20,30,40]
# ----> 5 result = reduce(lambda x, y :x + y,lists)
#       7 print(result)
#
# NameError: name 'reduce' is not defined

# %%
#Use reduce() with lambda to find the product of all numbers.
[2,3,4,5]
# Out:
# [2, 3, 4, 5]

# %%
#Sort the following list according to age.
students = [
("Ram",22),
("Amit",19),
("Neha",25),
("Raj",20)
]


students = [
("Ram",22),
("Amit",19),
("Neha",25),
("Raj",20)
]
result =sorted(students,key = lambda  x :x[1])
               
print(result)
# Out:
# [('Amit', 19), ('Raj', 20), ('Ram', 22), ('Neha', 25)]

# %%
#Sort the following dictionary by values.
marks = {
"A":80,
"B":95,
"C":70,
"D":88
}

marks = {
"A":80,
"B":95,
"C":70,
"D":88
}
result = sorted(marks.items(),key = lambda x :x[1])
print(result)
# Out:
# [('C', 70), ('A', 80), ('D', 88), ('B', 95)]

# %%
#Find the longest string using lambda.
#["apple","banana","kiwi","watermelon"]

fruits =["apple","banana","kiwi","watermelon"]
longest = max(fruits,key = lambda x : len(x))
print(longest)
# Out:
# watermelon

# %%
#16.
#Use lambda with max() to find the student having the highest marks.
students = [
("Ram",85),
("Amit",91),
("Neha",78)
]

students = [
("Ram",85),
("Amit",91),
("Neha",78)
]
result = max(students,key = lambda x: x[1])
print(result)
# Out:
# ('Amit', 91)

# %%
#Use lambda with min() to find the employee with the lowest salary.
employees = [
("A",35000),
("B",42000),
("C",28000)
]

employees = [
("A",35000),
("B",42000),
("C",28000)
]
result = min(employees,key = lambda x: x[1])
print(result)
# Out:
# ('C', 28000)

# %%
#Use map() with lambda to convert all names into uppercase.
#["ram","amit","neha"]

lists = ["ram","amit","neha"]
result = list(map( lambda x : x.upper(),lists))
print(result)
# Out:
# ['RAM', 'AMIT', 'NEHA']

# %%
#Filter all words having length greater than 5.
#["apple","banana","kiwi","orange","grapes"]

frutis =["apple","banana","kiwi","orange","grapes"]
result = list(filter(lambda x: len(x) > 5 ,fruits))
print(result)
# Out:
# ['banana', 'watermelon']

# %%
#Sort tuples based on the second element.
#[(1,5),(3,2),(2,8),(4,1)]

lists =[(1,5),(3,2),(2,8),(4,1)]
result =sorted(lists,key = lambda  x :x[1])
print(result)
# Out:
# [(4, 1), (3, 2), (1, 5), (2, 8)]

# %%
#21.Sort the following list of dictionaries based on salary.
employees = [
{"name":"Ram","salary":50000},
{"name":"Amit","salary":65000},
{"name":"Neha","salary":45000}
]

employees = [
{"name":"Ram","salary":50000},
{"name":"Amit","salary":65000},
{"name":"Neha","salary":45000}
]

result = list(sorted(employees,key = lambda x :x["salary"]))
print(result)
# Out:
# [{'name': 'Neha', 'salary': 45000}, {'name': 'Ram', 'salary': 50000}, {'name': 'Amit', 'salary': 65000}]

# %%
#Sort students by marks descending and name ascending.
# students = [
("Ram",90),
("Amit",90),
("Neha",85),
("Raj",95)
#]


students =[
("Ram",90),
("Amit",90),
("Neha",85),
("Raj",95)
]
result = list(sorted(students,key = lambda x :x[1]))
print(result)
# Out:
# [('Neha', 85), ('Ram', 90), ('Amit', 90), ('Raj', 95)]

# %%
#Use nested lambda to multiply two numbers.

mul = lambda a,b: a*b
mul(10,5)
# Out:
# 50

# %%
#Create a lambda that returns another lambda for exponentiation.


square = lambda x: x*x
print(square(6))
# Out:
# 36

# %%
#Using lambda and filter(), remove all negative numbers.
[-5,10,-3,8,0,-1,20]

lists =[-5,10,-3,8,0,-1,20]
result =list(filter(lambda x: x >= 0,lists))
print(result)
# Out:
# [10, 8, 0, 20]

# %%
#Using lambda and map(), replace every odd number by its square while leaving even numbers uncharged
[1,2,3,4,5,6]

lists =[1,2,3,4,5,6]
result =list( map(lambda x : x**2 if x % 2 != 0 else x,lists))
print(result)
# Out:
# [1, 2, 9, 4, 25, 6]

# %%
#Sort strings based on their last character.
["apple","banana","kiwi","grape"]

fruits =["apple","banana","kiwi","grape"]
result = sorted(fruits,key = lambda x : x[-1])
print(result)
# Out:
# ['banana', 'apple', 'grape', 'kiwi']

# %%
#Find the second highest salary using lambda.
employees = [
("A",45000),
("B",60000),
("C",52000),
("D",75000)
]

employees = [
("A",45000),
("B",60000),
("C",52000),
("D",75000)
]
result = sorted(employees, key = lambda x : x[1],reverse = True)
print(result[1])
# Out:
# ('B', 60000)

# %%
#29.Sort a list of dictionaries by age ascending and then salary descending.
employees = [
{"name":"Ram","age":25,"salary":50000},
{"name":"Amit","age":25,"salary":60000},
{"name":"Neha","age":23,"salary":45000},
{"name":"Raj","age":27,"salary":55000}
]

employees = [
{"name":"Ram","age":25,"salary":50000},
{"name":"Amit","age":25,"salary":60000},
{"name":"Neha","age":23,"salary":45000},
{"name":"Raj","age":27,"salary":55000}
]
result = sorted(employees, key = lambda x:x[1],reverse =False)
print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[160], line 15
#       2 employees = [
#       3 {"name":"Ram","age":25,"salary":50000},
#       4 {"name":"Amit","age":25,"salary":60000},
#       5 {"name":"Neha","age":23,"salary":45000},
#       6 {"name":"Raj","age":27,"salary":55000}
#       7 ]
#       9 employees = [
#      10 {"name":"Ram","age":25,"salary":50000},
#      11 {"name":"Amit","age":25,"salary":60000},
#      12 {"name":"Neha","age":23,"salary":45000},
#      13 {"name":"Raj","age":27,"salary":55000}
#      14 ]
# ---> 15 result = sorted(employees, key = lambda x:x[1],reverse =False)
#      16 print(result)
#
# Cell In[160], line 15, in <lambda>(x)
#       2 employees = [
#       3 {"name":"Ram","age":25,"salary":50000},
#       4 {"name":"Amit","age":25,"salary":60000},
#       5 {"name":"Neha","age":23,"salary":45000},
# ...
