# %%
text = input("enter the value:")
if text == text[::-1]:
   print(f"{text}is a palindrome")
else:
   print(f"{text}is not palindrome")
# Out:
# enter the value: madam
# madamis a palindrome

# %%
name = input("enter the name:")
if name == name[::-1]:
   print(f"palindrome :{name}")
else:
   print(f"not palindrome :{name}")
# Out:
# enter the name: mom
# palindrome :mom

# %%
text = input("enter the value:")
if text == text[::-1]:
    print(" is palindrome")
else:
    print(" is not palindrome")
# Out:
# enter the value: sandy
#  is not palindrome

# %%
marks =int(input("enter the marks:"))

if  80 < marks <= 90:
           print("excellent result")
elif 70 < marks >=80:
           print("average result")
elif  45 < marks <=70:
           print("passed")
else :
           print("failed")
# Out:
# enter the marks: 92
# average result

# %%
s ={1,2,2,3}
print(s)
# Out:
# {1, 2, 3}

# %%
tup =([1,2,3])
tup
# Out:
# [1, 2, 3]

# %%
set ={1,2,3,2,4,1}
set
# Out:
# {1, 2, 3, 4}

# %%
set ={10,20,30}
set.update([40,50,60])
set
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
set ={10,20,30,40}
set.remove(20)
set
# Out:
# {10, 30, 40}

# %%
A ={1,2,3,4}
B ={3,4,5,6}
A.union(B)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
A.intersection(B)
# Out:
# {3, 4}

# %%
A.difference(B)
# Out:
# {1, 2}

# %%
list = [1, 2, 2, 3, 4, 4, 5] 
set ={1,2,2,3,4,4,5}
len(set)
# Out:
# 5

# %%
set = input({"enter the values:"})
set
