# %% [markdown]
# #replace the word

# %%
name="my name is sandy"
name.replace("sandy","sandhya")
# Out:
# 'my name is sandhya'

# %%
name=name.replace("sandy","sandhya")
name
# Out:
# 'my name is sandhya'

# %%
text=input("enter the string:")
print(text.replace("","-"))
# Out:
# enter the string: santosh
# -s-a-n-t-o-s-h-

# %%
#

# %%
text=input("enter the string:")
print(text.rstrip())
# Out:
# enter the string:     today task is completed    .
#     today task is completed    .

# %%
course_name="   data science    "
print(course_name)
course_name.strip()
# Out:
#    data science
# 'data science'

# %% [markdown]
# text="hello.com"
# text.startswith("hello")
# text.endswith(".com")

# %%
fruits=("apple , mango , banana")
fruits.split("   ")
# Out:
# ['apple , mango , banana']

# %%
list=("apple","mango","grapes","promoganrt")
(" ".join(list))
# Out:
# 'apple mango grapes promoganrt'

# %% [markdown]
# # create a list [" python "," is "," awesome "].strip each word and join them

# %%
list= ["  python "," is ","awesome   "]
list[0]=list[0].strip()
list[1]=list[1].strip()
list[2]=list[2].strip()
list
("-".join(list))
# Out:
# 'python-is-awesome'

# %%
name =("devokethe sandhya rani")
name.split()

# %%
city1=input("enter the city1:")
city2=input("enter the city2:")
city3=input("enter the city3:")
city4=input("enter the city4:")
city5=input("enter the city5:")
cities=(city1,city2,city3,city4,city5)
print("\n".join(cities))

# %%
text=input("enter the sentence")
word=text.split()

# %%
n1=input("enter na
