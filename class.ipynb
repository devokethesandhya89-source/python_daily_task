# %%
#1. Create a class Student with instance attributes name and age. Create two objects
#and print their details.

class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

s1 = Student("Sandhya", 20)
s2 = Student("Rahul", 21)

print(s1.name, s1.age)
print(s2.name, s2.age)
# Out:
# Sandhya 20
# Rahul 21

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year

c = Car("Toyota", "Innova", 2023)

print("Brand:", c.brand)
print("Model:", c.model)
print("Year:", c.year)
# Out:
# Brand: Toyota
# Model: Innova
# Year: 2023

# %%
class Book:
    def __init__(self, title, author, price):
        self.title = title
        self.author = author
        self.price = price

    def display_info(self):
        print("Title:", self.title)
        print("Author:", self.author)
        print("Price:", self.price)

b = Book("Python", "Guido", 500)
b.display_info()
# Out:
# Title: Python
# Author: Guido
# Price: 500

# %%
class Employee:
    def __init__(self, emp_id, name, salary):
        self.emp_id = emp_id
        self.name = name
        self.salary = salary

e1 = Employee(101, "Ram", 25000)
e2 = Employee(102, "Ravi", 30000)
e3 = Employee(103, "Sita", 35000)

print(e1.emp_id, e1.name, e1.salary)
print(e2.emp_id, e2.name, e2.salary)
print(e3.emp_id, e3.name, e3.salary)
# Out:
# 101 Ram 25000
# 102 Ravi 30000
# 103 Sita 35000

# %%
class Mobile:
    def __init__(self, brand, price, color):
        self.brand = brand
        self.price = price
        self.color = color

    def __str__(self):
        return f"{self.brand} {self.price} {self.color}"

m = Mobile("Samsung", 20000, "Black")
print(m)
# Out:
# Samsung 20000 Black

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

r = Rectangle(10, 5)

print("Area =", r.area())
# Out:
# Area = 50

# %%
class Person:
    def __init__(self, name, city):
        self.name = name
        self.city = city

p = Person("Sandhya", "Hyderabad")

print("Before:", p.name, p.city)

p.city = "Warangal"

print("After:", p.name, p.city)
# Out:
# Before: Sandhya Hyderabad
# After: Sandhya Warangal

# %%
class Laptop:
    def __init__(self, brand, price):
        self.brand = brand
        self.price = price

l1 = Laptop("Dell", 50000)
l2 = Laptop("HP", 45000)
l3 = Laptop("Lenovo", 55000)

print(l1.brand, l1.price)
print(l2.brand, l2.price)
print(l3.brand, l3.price)
# Out:
# Dell 50000
# HP 45000
# Lenovo 55000

# %%
class Student:
    school_name = "City School"

s1 = Student()

print(Student.school_name)
print(s1.school_name)
# Out:
# City School
# City School

# %%
class Bank:
    bank_name = "SBI"

b1 = Bank()
b2 = Bank()

print(b1.bank_name)
print(b2.bank_name)

Bank.bank_name = "HDFC"

print(b1.bank_name)
print(b2.bank_name)
# Out:
# SBI
# SBI
# HDFC
# HDFC

# %%
class Counter:
    count = 0

    def increment(self):
        Counter.count += 1

c1 = Counter()
c2 = Counter()

c1.increment()
c2.increment()

print(Counter.count)
# Out:
# 2

# %%
class Employee:
    company = "ABC Corp"

e1 = Employee()
e2 = Employee()
e3 = Employee()

print(e1.company)
print(e2.company)
print(e3.company)
# Out:
# ABC Corp
# ABC Corp
# ABC Corp

# %%
class Circle:
    pi = 3.14

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return Circle.pi * self.radius * self.radius

c = Circle(5)
print("Area =", c.area())
# Out:
# Area = 78.5

# %%
class MathUtils:
    version = "1.0"

print(MathUtils.version)
# Out:
# 1.0

# %%
class Player:
    team = "India"      # Class attribute

    def __init__(self, name):
        self.name = name    # Instance attribute

p1 = Player("Virat")
p2 = Player("Rohit")

print(p1.team, p1.name)
print(p2.team, p2.name)
# Out:
# India Virat
# India Rohit

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

b = BankAccount(5000)

print(b._BankAccount__balance)
# Out:
# 5000

# %%
class Student:
    def __init__(self, marks):
        self.__marks = marks

s = Student(90)

print(s._Student__marks)
# Out:
# 90

# %%
class Employee:
    def __init__(self, salary):
        self.__salary = salary

e = Employee(30000)

print(e._Employee__salary)
# Out:
# 30000

# %%
class Product:
    def __init__(self, price):
        self.__price = price

p = Product(500)

print(p._Product__price)
# Out:
# 500

# %%
class User:
    def __init__(self, password):
        self.__password = password

u = User("Python123")

print(u._User__password)
# Out:
# Python123

# %%
class Car:
    def __init__(self, model, year):
        self.__model = model
        self.__year = year

c = Car("Swift", 2024)

print(c._Car__model)
print(c._Car__year)
# Out:
# Swift
# 2024

# %%
class Account:
    def __init__(self, account_number):
        self.__account_number = account_number

a = Account(123456789)

print(a._Account__account_number)
# Out:
# 123456789

# %%
class Student:
    def __init__(self, marks):
        self.__marks = marks

    def get_marks(self):
        return self.__marks

    def set_marks(self, marks):
        self.__marks = marks

s = Student(80)

print("Marks:", s.get_marks())

s.set_marks(95)
print("Updated Marks:", s.get_marks())
# Out:
# Marks: 80
# Updated Marks: 95

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def get_balance(self):
        return self.__balance

    def set_balance(self, balance):
        if balance >= 0:
            self.__balance = balance
        else:
            print("Invalid Balance")

b = BankAccount(5000)

print(b.get_balance())

b.set_balance(7000)
print(b.get_balance())

b.set_balance(-100)
# Out:
# 5000
# 7000
# Invalid Balance

# %%
class Employee:
    def __init__(self, salary):
        self.__salary = salary

    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        if salary >= 5000:
            self.__salary = salary
        else:
            print("Salary should be at least 5000")

e = Employee(10000)

print(e.get_salary())

e.set_salary(6000)
print(e.get_salary())

e.set_salary(3000)
# Out:
# 10000
# 6000
# Salary should be at least 5000

# %%
class Temperature:
    def __init__(self, celsius):
        self.__celsius = celsius

    def get_celsius(self):
        return self.__celsius

    def get_fahrenheit(self):
        return (self.__celsius * 9/5) + 32

    def set_celsius(self, celsius):
        self.__celsius = celsius

t = Temperature(25)

print("Celsius:", t.get_celsius())
print("Fahrenheit:", t.get_fahrenheit())
# Out:
# Celsius: 25
# Fahrenheit: 77.0

# %%
class Person:
    def __init__(self, age):
        self.__age = age

    def get_age(self):
        return self.__age

    def set_age(self, age):
        if 0 <= age <= 120:
            self.__age = age
        else:
            print("Invalid Age")

p = Person(20)

print(p.get_age())

p.set_age(35)
print(p.get_age())

p.set_age(150)
# Out:
# 20
# 35
# Invalid Age

# %%
class Product:
    def __init__(self, price):
        self.__price = price

    def get_price(self):
        return self.__price

    def set_price(self, price):
        if price > 1000:
            self.__price = price * 0.9
        else:
            self.__price = price

p = Product(500)

print(p.get_price())

p.set_price(2000)
print(p.get_price())
# Out:
# 500
# 1800.0

# %%
class Mobile:
    def __init__(self, price):
        self.__price = price

    def get_price(self):
        return self.__price

    def set_price(self, price):
        self.__price = price
        print("Price Updated")

m = Mobile(15000)

print(m.get_price())

m.set_price(18000)

print(m.get_price())
# Out:
# 15000
# Price Updated
# 18000

# %%
class Rectangle:
    def __init__(self, length, width):
        self.__length = length
        self.__width = width

    def get_length(self):
        return self.__length

    def get_width(self):
        return self.__width

    def set_length(self, length):
        self.__length = length

    def set_width(self, width):
        self.__width = width

    def area(self):
        return self.__length * self.__width

r = Rectangle(5, 4)

print("Area:", r.area())

r.set_length(10)
r.set_width(6)

print("New Area:", r.area())
# Out:
# Area: 20
# New Area: 60

# %%
#1. (Hard) Create class Employee with private attribute __salary. Add getter and
#setter with these conditions in setter:
#• Salary cannot be less than 5000.
#• Salary cannot be increased by more than 20% at once.
#• Keep track of last updated salary using class attribute . add class method get_total_employee()
# Out:
#   Cell In[15], line 25
#     def get_total_employee(cls):
#     ^
# IndentationError: unexpected indent
