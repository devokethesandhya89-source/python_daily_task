# %%
#1-5: Functions with No Parameters
#1. Write a function greet() that prints "Hello, Welcome to Python!".

def greet():
    return "Hello , welcome to python!"

# %%
greet()
# Out:
# 'Hello , welcome to python!'

# %%
#2. Create a function show_date() that prints the current date and time.

from datetime import datetime
def show_data():
     return datetime.now()
show_data()
# Out:
# datetime.datetime(2026, 7, 17, 14, 37, 43, 873966)

# %%
#3. Write a function print_square() that prints the square of numbers from 1 to 10

def square():
    result = []
    for i in range(1, 10):
        result.append(i**2)
    return result

square()
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
#4. Make a function motivation() that prints any motivational quote.


def motivation():
    return " if u belive in yourself anithing is possible"
motivation()
# Out:
# ' if u belive in yourself anithing is possible'

# %%
#5. Write a function line() that prints 50 dashes (-).

def line():
    return ("-" *50)
line()
# Out:
# '--------------------------------------------------'

# %%
#6. Write a function greet_user(name="Guest") that greets the user.

def greet_user(name="guest"):
     return f"hi {name},good morning"

# %%
greet_user("sandy")
# Out:
# 'hi sandy,good morning'

# %%
#7. Create a function power(base, exp=2) that returns base raised to exp.

def power(base,exp=2):
     return base **exp
    
power(5)
# Out:
# 25

# %%
#8. Write a function student_info(name, age=18, city="Delhi").

def info(name,age,city):
    return f" hii {name},{age},{city}"
info(name="sandy",age = 18,city ="delhi")
# Out:
# ' hii sandy,18,delhi'

# %%
#9. Make a function add_numbers(a, b=0, c=0) that returns sum of three numbers.

def add_num(a=0,b=0,c=0):
    return a+b+c
add_num(10,20,30)
# Out:
# 60

# %%
#10. Write a function repeat_message(msg, times=3) that prints message times times.

def repeat_message(msg, times=3):
     for i in range(times):
         return(msg)
repeat_message( "hii sandy")
# Out:
# 'hii sandy'

# %%
#11. Create a function calculate_discount(price, discount=10).

def calculate_discount(price,discount=10):
    return price*discount/100
calculate_discount(4990)
# Out:
# 499.0

# %%
#12. Write a function introduce(name="Unknown", profession="Student").

def introduce(name="unknown",profession="student"):
    return f" good morning sir iam {name},iam a {profession}"
introduce(name ="sandhya",profession ="student")
# Out:
# ' good morning sir iam sandhya,iam a student'

# %%
#13. Write a function full_name(first, last) and call it using positional arguments.

def full_name(first,last):
    return {first},{last}
full_name("devokethe","sandhya")
# Out:
# ({'devokethe'}, {'sandhya'})

# %%
#14. Call the same function using keyword arguments.

def info(name,age):
    return f"name:{name},name:{age}"
info(name ="sandy",age = 21)
# Out:
# 'name:sandy,name:21'

# %%
#15. Write a function details(name, age, city) and demonstrate both positional and keyword calls

def details(name,age,city):
    return f"name:{name},age:{age},city:{city}"
details(name ="sandhya",city = "hyd",age =21)
# Out:
# 'name:sandhya,age:21,city:hyd'

# %%
#16. Create a function calculate(a, b, operation) and show how keyword args improve readability

def calculate(a,b):
     return a + b
calculate(3, 5)
# Out:
# 8

# %%
#17. Write a function order(item, quantity, price) and call it with mixed positional + keyword.

def order(item,quantity,price):
    return f"item:{item},quantity:{quantity},price:{price}"
order(item="laptop",quantity="very good",price = 7500)
# Out:
# 'item:laptop,quantity:very good,price:7500'

# %%
#18. What is the advantage of using keyword arguments over positional?

## no need to any order while passing the paremeters
## enhance the code relaibility
## safer modifications55
## flexible defaults

# %%
#19. Write a function add_all(*args) that returns sum of all numbers passed.

def add_all(*args):
    return sum(args)

add_all(1,2,3,4,5)
# Out:
# 15

# %%
#20. Create a function print_all(*args) that prints all arguments.

def print_all(*args):
    return print(args)
print_all(1,2,3,4,5,6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#21. Write a function find_max(*args) that returns the maximum value.

def find_max(*args):
    return max(args)
find_max(10,30,50,80,90)
# Out:
# 90

# %%
#22. Make a function concatenate(*args) that joins all string arguments with space.

def concatenate(*args):
    return " ".join(args)
concatenate("python" , "is" , "easy")
# Out:
# 'python is easy'

# %%
#23. Write a function multiply(*args) that multiplies all numbers.

def multiply(*args):
    result = 1
    for i in args:
         result *= i
    return result
multiply(2,3,4)
# Out:
# 24

# %%
#24. Create a function that takes student marks as *args and returns average.

def student_marks(*args):
    result =0
    if

# %%
#25. Write a function info(*args) that prints type and value of each argument.

def info(*args):
    for items in args:
        return f"Type:{type(item)},value:{item}"
info()

# %%
class Employee:

    def __init__(self, emp_id, salary, pf_money):
        self.__employee_id = emp_id
        self.__employee_salary = salary
        self.__employee_pf_money = pf_money

    def get_employee_salary(self):
        return self.__employee_salary

    def get_employee_pf_amount(self):
        return self.__employee_pf_money
    
    def set_employee_salary(self, salary):
        if salary > 10000:
           self.__employee_salary = salary
        else: 
           print(f"salary must be greater than 10000")
    def set_employee_pf_money(self, pf_money):
        if pf_money >1000:
           self.__employee_pf_money = pf_money
        else:
            print(f"pf_money must be greater than 1000")
    def display_employee_details(self):
        print(f"employee_id :{self.__employee_id}")
        print(f"employee_salary :{self.__employee_salary}")
        print(f"employee pf_money:{self.__employee_pf_money}")


# Example usage
emp = Employee("san123", 50000, 500)

print("salary:",emp.get_employee_salary())
print("pf_money:",emp.get_employee_pf_money())

emp.set_employee_salary(50000)
emp.set_employee_pf_money(5000)
emp.display_employee_details()
# Out:
# salary: 50000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 34
#      31 emp = Employee("san123", 50000, 500)
#      33 print("salary:",emp.get_employee_salary())
# ---> 34 print("pf_money:",emp.get_employee_pf_money())
#      36 emp.set_employee_salary(50000)
#      37 emp.set_employee_pf_money(5000)
#
# AttributeError: 'Employee' object has no attribute 'get_employee_pf_money'

# %% [markdown]
# #type of oops concepts
#
# # enapsulation

# %%
syntax:
class class_name:
   #constructor
    def __init__(self,args):
        self.__variable_name = args #private attribute
   # accesor
    def get_private_attribute_name(self):  #access the private attribute
        return(self.__variable_name)
  # #setter
    def set_private_attribute_name(self):
        #block of code

# %%
# without encapsulation
class Bank_account:
    # constructor:
    def __init__(self,owner,bal):

    # create attributes
     self.owner_name = owner
     self.Bank_balance = bal

    # method 1:
    def display_bank_details(self):
        print(f" ownwr Name :{self.owner_name }")
        print(f" Bank balance :{self.Bank_balance}")

# create the class object
bank1 = Bank_account("sandy",200)

# call the method
bank1.display_bank_details()
# Out:
#  ownwr Name :sandy
#  Bank balance :200

# %%
bank1.Bank_balance
# Out:
# 200

# %%
# with encapsulation
class Bank_account:
    # constructor:
    def __init__(self,owner,bal):

    # create attributes
     self.owner_name = str(owner)
     self.__Bank_balance = int( bal)    # private attribute convertion

    #gatter :access the private attribute
    def get_balance(self):
        return self.__Bank_balance
    #setter : set_validation

    def set_balance(self,amt):
        if amt > 0:

            self.__Bank_balance += amt

            return self.__Bank_balance
        else:
            return "please enter the valid amt"

    # method 1: instance method
    def display_bank_details(self):
        print(f" ownwr Name :{self.owner_name }")
        print(f" Bank balance :{self.Bank_balance}")

# create the class object
bank1 = Bank_account("sandy",300)

# call the method
bank1.display_bank_details()
bank1.get_balance()
# Out:
#  ownwr Name :sandy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 33
#      30 bank1 = Bank_account("sandy",300)
#      32 # call the method
# ---> 33 bank1.display_bank_details()
#      34 bank1.get_balance()
#
# Cell In[8], line 27, in Bank_account.display_bank_details(self)
#      25 def display_bank_details(self):
#      26     print(f" ownwr Name :{self.owner_name }")
# ---> 27     print(f" Bank balance :{self.Bank_balance}")
#
# AttributeError: 'Bank_account' object has no attribute 'Bank_balance'

# %%
#Abstraction:

#take the parent :company
#take two args : name,desg
#get the private data
#make two abstarct methods :
# 1 : work
# 2 : salary
# display all info
name,role, work , salary
#create the two child class : employee , manager


class Company(ABC):
    def __init__(self,name,desg):
        self.__emp_name = e_name
        self.__emp_desg = e_desg
    #gatter
    def get_emp_name(self):
        return self.__emp_name
    def get_emp_desg(self):
        return self.__emp_desg
    #abstarct method
    @abstarctmethod
    def work(self):
        pass
    @abstarctmethod
    def salary(self):
        pass
    #dispaly the information
    def dispaly_all_details(self):
        print(f" emp name :{ self.__emp_name }")
        print(f" emp role:{ self.__emp_desg}")
        print(f" emp work:{ self.__emp_work}")
        print(f" emp salary:{ self.__emp_salary}")
#child 1

class employee(company):

    def work(self):
        print("develop the s
    def salary(self):
        print("
