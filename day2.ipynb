# %%
#factorial
num = int(input("Enter a number: "))
fact = 1

for i in range(1, num + 1):
    fact *= i

print("Factorial =", fact)
# Out:
# Enter a number:  10
# Factorial = 3628800

# %%
num=int(input("enter the value :"))
fact=1
for i in range(1,num+1+):
    fact *=i
    print("factorial=",fact)
