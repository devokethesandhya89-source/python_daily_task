# %%
Students=["sandhya","rupika","madhuri","vaishnavi","yashi"]
print(Students)
# Out:
# ['sandhya', 'rupika', 'madhuri', 'vaishnavi', 'yashi']

# %%
numbers=[10,20,30,40,50]
print(type(numbers))
print(len(numbers))
# Out:
# <class 'list'>
# 5

# %%
numbers=[]
numbers.append(10)
numbers.append(20)
numbers.append(30)
print(numbers)
# Out:
# [10, 20, 30]

# %%
lst=[1,2,3]
lst.extend([4,5,6])
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list=[10,20,30,40]
list.insert(2,100)
list
# Out:
# [10, 20, 100, 30, 40]

# %%
list=[10,20,50,30,50]
list.remove(50)
list
# Out:
# [10, 20, 30, 50]

# %%
list=[5,1,15,20]
print(list.pop(-1))
# Out:
# 20

# %%
data=[1,2,3,4,5]
data.clear()
data
# Out:
# []

# %%
list=[10,15,25,30,40]
print(list.index(25))
# Out:
# 2

# %%
list=[7,2,7,5,7,8]
list.count(7)
# Out:
# 3

# %%
list=[45,12,78,23,56]
list.sort()
list
# Out:
# [12, 23, 45, 56, 78]

# %%
list=[45,12,78,23,56]
list.sort(reverse=True)
list
# Out:
# [78, 56, 45, 23, 12]

# %%
fruits=["apple","banana","mango","orange"]
fruits.reverse()
fruits
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
list=[1,2,3,4]
copy_list=list.copy()
print(list)
print(copy_list)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
sentence=input("enter the sentence:")
words=sentence.split()
print(words)
# Out:
# enter the sentence: "i love python programming"
# ['"i', 'love', 'python', 'programming"']

# %%
list=[17,39,97,90,11]
list.append(70)
list.append(37)
list.sort(reverse=True)
list
# Out:
# [97, 90, 70, 39, 37, 17, 11]

# %%
list=[10,20,"sandy",33.4]
list.insert(0,"python")
list.pop(-1)
list
# Out:
# ['python', 10, 20, 'sandy']

# %%
data=[10,20,30,20,40,20]
while 20 in data:
    data.remove(20)
    print(data)
# Out:
# [10, 30, 20, 40, 20]
# [10, 30, 40, 20]
# [10, 30, 40]

# %%
marks=[56,48,53,49,51]
marks.sort()
print("sorted",marks)
print("highest marks:",max(marks))
print("lowest marks:",min(marks))
# Out:
# sorted [48, 49, 51, 53, 56]
# highest marks: 56
# lowest marks: 48
